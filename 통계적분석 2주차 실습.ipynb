# %%
import pandas as pd
import array as np

# %%
df=pd.read_csv('Downloads/source/python_stat_sample-master/data/ch1_sport_test.csv',
              index_col='학생번호')
df
# Out:
#       학년    악력  윗몸일으키기  점수  순위
# 학생번호
# 1      1  40.2      34  15   4
# 2      1  34.2      14   7  10
# 3      1  28.8      27  11   7
# 4      2  39.0      27  14   5
# 5      2  50.9      32  17   2
# 6      2  36.5      20   9   9
# 7      3  36.6      31  13   6
# 8      3  49.2      37  18   1
# 9      3  26.0      28  10   8
# 10     3  47.4      32  16   3

# %%
df ['악력']
# Out:
# 학생번호
# 1     40.2
# 2     34.2
# 3     28.8
# 4     39.0
# 5     50.9
# 6     36.5
# 7     36.6
# 8     49.2
# 9     26.0
# 10    47.4
# Name: 악력, dtype: float64

# %%
np=pd.read_csv('Downloads/source/python_stat_sample-master/data/ch2_scores_em.csv',
              index_col='student number')
np
# Out:
#                 english  mathematics
# student number
# 1                    42           65
# 2                    69           80
# 3                    56           63
# 4                    41           63
# 5                    57           76
# 6                    48           60
# 7                    65           81
# 8                    49           66
# 9                    65           78
# 10                   58           82
# 11                   70           94
# 12                   47           75
# 13                   51           70
# 14                   64           77
# 15                   62           84
# 16                   70           84
# 17                   71           82
# 18                   68           85
# 19                   73           90
# 20                   37           70
# 21                   65           78
# 22                   65           93
# 23                   61           77
# 24                   52           88
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 np.median(scores)
#
# NameError: name 'scores' is not defined
