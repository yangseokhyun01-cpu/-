# %%
import numpy as np
import matplotlib.pyplot as plt

# %precision 3
# %matplotlib inline

# %%
x_set=np.array([1,2,3,4,5,6])

# %%
def f(x):
    if x in x_set:
        return x / 21
    else:
        return 0

# %%
X=[x_set,f]

# %%
prob =np.array([f(x_k) for x_k in x_set])
dict(zip(x_set,prob))
# Out:
# {np.int64(1): 0.048,
#  np.int64(2): 0.095,
#  np.int64(3): 0.143,
#  np.int64(4): 0.190,
#  np.int64(5): 0.238,
#  np.int64(6): 0.286}

# %%
fig = plt.figure(figsize=(10,6))
ax=fig.add_subplot(111)
ax.bar(x_set,prob)
ax.set_xlabel('value')
ax.set_ylabel('probabaility')

plt.show()

# %%
a = {'사과':1,'딸기':5,'귤':10}

# %%
a
# Out:
# {'사과': 1, '딸기': 5, '귤': 10}

# %%
a={('초콜릿',200):20,('마카롱',500):15,('쿠키',300):30}

# %%
a
# Out:
# {('초콜릿', 200): 20, ('마카롱', 500): 15, ('쿠키', 300): 30}

# %%
a = {'사과':1,'딸기':5,'귤':10}
v1= a['딸기']
v1
# Out:
# 5

# %%
a={('초콜릿',200):20,('마카롱',500):15,('쿠키',300):30}
v1=a[('초콜릿',200)]
v1
# Out:
# 20

# %%
v2 = a['레몬']
v2
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 v2 = a['레몬']
#       2 v2
#
# KeyError: '레몬'

# %%
f1 = '딸기' in a
f1
# Out:
# True

# %%
f2 = '레몬' not in a
f2
# Out:
# True

# %%
f3 = '레몬' in a
f3
# Out:
# False

# %%
v1 = a.get('딸기')
v1
# Out:
# 5

# %%
v2 = a.get('레몬')
v2

# %%
a = {'초콜릿':1,'마카롱':2,'쿠키':3}
a['초콜릿'] = 'one'
a['마카롱'] = 'two'
a['쿠키'] = 'three'
a
# Out:
# {'초콜릿': 'one', '마카롱': 'two', '쿠키': 'three'}

# %%
d = dict(초콜릿=20,마카롱=15,쿠키=30)
d
# Out:
# {'초콜릿': 20, '마카롱': 15, '쿠키': 30}

# %%
d=dict([('초콜릿',20),('마카롱',15),('쿠키',30)])
d
# Out:
# {'초콜릿': 20, '마카롱': 15, '쿠키': 30}

# %%
np.all(prob>0)
# Out:
# np.True_

# %%
np.sum(prob)
# Out:
# 1.000

# %%
def F(x):
    return np.sum([f(x_k) for x_k in x_set if x_k <=x])

# %%
F(3)
# Out:
# 0.286

# %%
y_set = np.array([2*x_k+3 for x_k in x_set])
prob = np.array([f(x_k) for x_k in x_set])
dict(zip(y_set,prob))
# Out:
# {np.int64(5): 0.048,
#  np.int64(7): 0.095,
#  np.int64(9): 0.143,
#  np.int64(11): 0.190,
#  np.int64(13): 0.238,
#  np.int64(15): 0.286}

# %%
np.sum([x_k * f(x_k) for x_k in x_set])
# Out:
# 4.333

# %%
np.random.choice(5,5,replace = False)
# Out:
# array([3, 0, 1, 2, 4], dtype=int32)

# %%
np.random.choice(5,3,replace =False)
# Out:
# array([2, 0, 4], dtype=int32)

# %%
np.random.choice(5,10)
# Out:
# array([0, 3, 0, 1, 3, 4, 2, 4, 4, 1], dtype=int32)

# %%
np.random.choice(5,10,p=[0.1,0.2,0.3,0.4,0])
# Out:
# array([0, 0, 1, 3, 3, 3, 3, 1, 3, 3], dtype=int32)

# %%
sample = np.random.choice(x_set,int(1e6),p=prob) #p=prob?
np.mean(sample)
# Out:
# 4.332

# %%
def E(X , g=lambda x:x):
    x_set, f = X
    return np.sum([g(x_k) * f(x_k) for x_k in x_set])

# %%
E(X)
# Out:
# 4.333

# %%
E(X, g=lambda x: 2*x +3)
# Out:
# 11.667

# %%
2* E(X) +3
# Out:
# 11.667

# %%
string =['sdfsdggsdv','dsa','etefsdzvsdvsfdvgs']

# %%
string.sort(key=lambda x:len(set(list(x))))

# %%
string
# Out:
# ['dsa', 'sdfsdggsdv', 'etefsdzvsdvsfdvgs']

# %%
2 * E(X) +3
# Out:
# 11.667

# %%
mean = E(X)
np.sum([(x_k-mean)**2 * f(x_k) for x_k in x_set])
# Out:
# 2.222

# %%
def V(X , g=lambda x:x):
    x_set, f = X
    mean = E(X,g)
    return np.sum([(g(x_k)-mean)**2*f(x_k) for x_k in x_set])

# %%
V(X)
# Out:
# 2.222

# %%
V(X, lambda x: 2*x+3)
# Out:
# 8.889

# %%
2**2 *V(X)
# Out:
# 8.889
